# %%
print("hello world")
# Out:
# hello world

# %%
"""variables"""
a = 28     #integer
b= 1.5     #float
c = "hi"   #string
d = True   # bool
e = None   #NoneType

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))

print( a+b)
# print(a+c)  #typeError
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>
# 29.5

# %%
#string-formating

name = input("Name :")

# print("Hello" + " " + name)

#f-string
print(f"hello {name}")
# Out:
# Name : amir
# hello amir

# %%
#conditions
n = int(input("Number"))
if n > 0:
    print(" N is possetive")

elif n<0 :
    print("N is negetive")
    
else:
    print("N is 0")
# Out:
# Number -123
# N is negetive

# %%
#slicing
name = input("input ->")
print(name[1])
# Out:
# input -> amir
# m

# %%
#Data stracture 
names = ["Harry" , "Ron" , "mohadese" ,"sara" , "mohammad" , "hadi" , "zahra"]

print(names)
print(names[0])

names.append("sogol")
print(names)
print(sorted(names))
# Out:
# ['Harry', 'Ron', 'mohadese', 'sara', 'mohammad', 'hadi', 'zahra']
# Harry
# ['Harry', 'Ron', 'mohadese', 'sara', 'mohammad', 'hadi', 'zahra', 'sogol']
# ['Harry', 'Ron', 'hadi', 'mohadese', 'mohammad', 'sara', 'sogol', 'zahra']

# %%
#set
s = set()
s.add(1)
s.add(2)
s.add(3)

s.remove(2)
print(s)
print(f"the set has {len(s)} element")
# Out:
# {1, 3}
# the set has 2 element

# %%
#loop
"""ex1"""
# for i in range(10):
#     print(i)

"""ex2"""
# names = ["Harry" , "Ron" , "mohadese" ,"sara" , "mohammad" , "hadi" , "zahra"]
# for name in names:
#     print(name)

"""ex3"""
# char  =  "harry"
# for i in char:
#     print(i)
# Out:
# h
# a
# r
# r
# y

# %%
# dictionary
houses = {"Hamide" : "20" , "Helma" :"19.5"}
houses ["Hamide"] = "18"
print(houses["Hamide"])
# Out:
# 18

# %%
#function
"""ex1"""
# def square(x):
#      return x *x
# for i in range(10):
#     print(f"the square of {i} is {square(i)}")
# Out:
# the square of 0 is 0
# the square of 1 is 1
# the square of 2 is 4
# the square of 3 is 9
# the square of 4 is 16
# the square of 5 is 25
# the square of 6 is 36
# the square of 7 is 49
# the square of 8 is 64
# the square of 9 is 81

# %%
""""decorators"""
def announce(f):
    def wrapper():
        print("About to the run function")
        f()
        print("Done with the funct")
    return wrapper

@announce
def hello():
    print("hello world")
hello()
# Out:
# About to the run function
# hello world
# Done with the funct

# %%
""""lambda"""
peaple = [

    {"names":"Atiye" , "House":"inside"},
    {"names":"Mehdi" , "House":"outside"},
    {"names":"elnaz" , "House":"inside"}
]

peaple.sort(key=lambda person:person["names"])
print(peaple)
# Out:
# [{'names': 'Atiye', 'House': 'inside'}, {'names': 'Mehdi', 'House': 'outside'}, {'names': 'elnaz', 'House': 'inside'}]

# %%
import sys
try:
    x = int(input())
    y = int(input())
except ValueError:
    print("value does not correct")
try:
    result = x/y
except ZeroDivisionError:
    print("Error , cannt devided by 0")
    sys.exit(1)

print(f"{x} / {y} == {result}")
# Out:
#  12
#  sa
# value does not correct
# 12 / 2 == 6.0
